# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df_lt = pd.read_csv('cnes_LT.csv', encoding = "ISO-8859-1", sep = ';', low_memory=False, index_col=None)

# %%
df_lt.shape
# Out:
# (572728, 28)

# %%
df_lt.head(10)
# Out:
#       CNES  CODUFMUN REGSAUDE MICR_REG  DISTRSAN DISTRADM TPGESTAO  PF_PJ  \
# 0  2384035    521950        1      NaN       NaN      NaN        D      3
# 1  2384035    521950        1      NaN       NaN      NaN        D      3
# 2  2384035    521950        1      NaN       NaN      NaN        D      3
# 3  2384035    521950        1      NaN       NaN      NaN        D      3
# 4  2384035    521950        1      NaN       NaN      NaN        D      3
# 5  2507722    520030        3      NaN       NaN      NaN        D      3
# 6  2507722    520030        3      NaN       NaN      NaN        D      3
# 7  2507722    520030        3      NaN       NaN      NaN        D      3
# 8  2507722    520030        3      NaN       NaN      NaN        D      3
# 9  2507722    520030        3      NaN       NaN      NaN        D      3
#
#         CPF_CNPJ  NIV_DEP  ...  NIV_HIER  TERCEIRO  TP_LEITO  CODLEITO  \
# 0              0        3  ...       6.0       2.0         1         3
# ...
